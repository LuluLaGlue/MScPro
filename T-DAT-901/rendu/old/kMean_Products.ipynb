# %% [markdown]
# # Cluster Products

# %%
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import pickle
import os

# %%
df = pd.read_csv("..{}data{}KaDo_Products.csv".format(os.sep, os.sep), sep=",")
df = df.drop(columns=df.columns[0], axis=1)

df.head()
# Out:
#            FAMILLE                 MAILLE                   UNIVERS  \
# 0       MAQUILLAGE        MAQ_LEV_BASPRIX          MAQ_LEV BRILLANT
# 1       MAQUILLAGE        MAQ_LEV_BASPRIX          MAQ_LEV BRILLANT
# 2  SOINS DU VISAGE     VIS_JEUNE_ET_LEVRE           VIS_SOIN LEVRES
# 3   SOINS DU CORPS   CORPS_SPA_ET_MINCEUR        CORPS_SOINS HAMMAM
# 4   SOINS DU CORPS  CORPS_HYDR_LAIT_HUILE  CORPS_LAIT HUILE PARFUMS
#
#                              LIBELLE  PRIX_NET
# 0   GLOSS TRANSPARENCE LU HV06 4.5ML      3.95
# 1  GLOSS SEXYPULP CORAIL 01 CN3 10ML      9.95
# 2   BAUME LEVR REPAIR REPACK 2012 4G      2.50
# 3      MASQUE VIS TRAD DE HAM T100ml      8.95
# 4               LAIT ROSE FP FL200ML      4.45

# %%
df.shape[0]
# Out:
# 1484

# %% [markdown]
# ### Prepare DF

# %% [markdown]
# Using Categorical

# %%
CATEGORIES = []

CATEGORIES.extend(df["LIBELLE"].unique().tolist())
CATEGORIES.extend(df["FAMILLE"].unique().tolist())
CATEGORIES.extend(df["MAILLE"].unique().tolist())
CATEGORIES.extend(df["UNIVERS"].unique().tolist())

CATEGORIES = list(dict.fromkeys(CATEGORIES))

CATEGORIES[:5]
# Out:
# ['GLOSS TRANSPARENCE LU HV06 4.5ML',
#  'GLOSS SEXYPULP CORAIL 01 CN3 10ML',
#  'BAUME LEVR REPAIR REPACK 2012 4G',
#  'MASQUE VIS TRAD DE HAM T100ml',
#  'LAIT ROSE FP FL200ML']

# %%
df["LIBELLE"] = pd.Categorical(df["LIBELLE"], categories=CATEGORIES)
df["LIBELLE"] = df["LIBELLE"].cat.codes

df["FAMILLE"] = pd.Categorical(df["FAMILLE"], categories=CATEGORIES)
df["FAMILLE"] = df["FAMILLE"].cat.codes

df["MAILLE"] = pd.Categorical(df["MAILLE"], categories=CATEGORIES)
df["MAILLE"] = df["MAILLE"].cat.codes

df["UNIVERS"] = pd.Categorical(df["UNIVERS"], categories=CATEGORIES)
df["UNIVERS"] = df["UNIVERS"].cat.codes

df.head(10)
# Out:
#    FAMILLE  MAILLE  UNIVERS  LIBELLE  PRIX_NET
# 0     1484    1493     1527        0      3.95
# 1     1484    1493     1527        1      9.95
# 2     1485    1494     1528        2      2.50
# 3     1486    1495     1529        3      8.95
# 4     1486    1496     1530        4      4.45
# 5     1487    1497     1531        5      9.90
# 6     1485    1494     1532        6      5.95
# 7     1488    1498     1533        7      6.45
# 8     1484    1499     1534        8      9.00
# 9     1484    1500     1535        9      3.00

# %% [markdown]
# ### Train Model

# %%
kmeans = KMeans(n_clusters=20, n_init=100, max_iter=1000, algorithm="full")

kmeans.fit(df)

kmeans.labels_
# Out:
# array([2, 2, 2, ..., 3, 3, 3])

# %% [markdown]
# ### Save Clusters

# %%
pickle.dump(kmeans, open("..{}models{}model_products_20.pkl".format(os.sep, os.sep), "wb"))

# %% [markdown]
# # Apply Model to Client

# %%
df_history = pd.read_csv("..{}data{}KaDo.csv".format(os.sep, os.sep), sep=",")
df_products = pd.read_csv("..{}data{}KaDo_Products.csv".format(os.sep, os.sep), sep=",")

df_products = df_products.drop(columns=df_products.columns[0], axis=1)
df_all = df_history.copy()
df_history.head()
# Out:
#    TICKET_ID  MOIS_VENTE  PRIX_NET          FAMILLE  \
# 0   35592159          10      1.67          HYGIENE
# 1   35592159          10      1.66          HYGIENE
# 2   35592159          10      7.45  SOINS DU VISAGE
# 3   35592159          10      5.95  SOINS DU VISAGE
# 4   35592159          10      1.67          HYGIENE
#
#                        UNIVERS                MAILLE  \
# 0       HYG_DOUCHE JARDINMONDE               HYG_JDM
# 1       HYG_DOUCHE JARDINMONDE               HYG_JDM
# 2  VIS_CJOUR Jeunes Specifique    VIS_JEUNE_ET_LEVRE
# 3               VIS_DEMAQ AAAR  VIS_AAAR_DEMAQLOTION
# 4       HYG_DOUCHE JARDINMONDE               HYG_JDM
#
#                            LIBELLE   CLI_ID
# 0    GD JDM4 PAMPLEMOUSSE FL 200ML  1490281
# 1    GD JDM4 PAMPLEMOUSSE FL 200ML  1490281
# 2  CR JR PARF BIO.SPE AC.SENT.50ML  1490281
# 3    EAU MICELLAIRE 3 THES FL200ML  1490281
# 4           GD JDM4 TIARE FL 200ML  1490281

# %% [markdown]
# #### Extract Client

# %%
CLIENT_ID = 984943411  # 984943411  # 13290776

# %%
df_history = df_history[df_history["CLI_ID"] == CLIENT_ID]

df_history.head(20)
# Out:
#          TICKET_ID  MOIS_VENTE  PRIX_NET         FAMILLE  \
# 3643163   32991432           1      2.95     CAPILLAIRES
# 3643164   32991432           1      2.95     CAPILLAIRES
# 3643165   32991432           1      1.95         HYGIENE
# 3643166   32991432           1     17.50       PARFUMAGE
# 3643167   32991432           1      1.95         HYGIENE
# 3643168   33278153           2      2.95     CAPILLAIRES
# 3643169   33278153           2      2.95     CAPILLAIRES
# 3643170   33278153           2      1.95         HYGIENE
# 3643171   33278153           2      1.50         HYGIENE
# 3643172   33278153           2      1.50         HYGIENE
# 3643173   33492385           2      1.95         HYGIENE
# 3643174   33492385           2      1.95         HYGIENE
# 3643175   33492385           2      1.50  SOINS DU CORPS
# 3643176   33492385           2      5.90     CAPILLAIRES
# 3643177   33492385           2      5.90     CAPILLAIRES
# 3643178   33492385           2      5.90     CAPILLAIRES
# 3643179   33492385           2      5.95  SOINS DU CORPS
# 3643180   33653818           3      5.90     CAPILLAIRES
# 3643181   33653818           3     12.00  SOINS DU CORPS
# 3643182   33653818           3      9.25      MAQUILLAGE
#
#                                 UNIVERS                 MAILLE  \
# 3643163                    CAP_AP SHAMP       CAPILLAIRE_AUTRE
# 3643164                    CAP_AP SHAMP       CAPILLAIRE_AUTRE
# 3643165        HYG_DOUCHE FRAICHEUR VEG             HYG_AUTRES
# 3643166               PARF_EAUX PARFUMS            PARF_PARFUM
# 3643167        HYG_DOUCHE FRAICHEUR VEG             HYG_AUTRES
# 3643168                    CAP_AP SHAMP       CAPILLAIRE_AUTRE
# 3643169                    CAP_AP SHAMP       CAPILLAIRE_AUTRE
# 3643170        HYG_DOUCHE FRAICHEUR VEG             HYG_AUTRES
# 3643171          HYG_DOUCHE JARDINMONDE                HYG_JDM
# 3643172          HYG_DOUCHE JARDINMONDE                HYG_JDM
# 3643173        HYG_DOUCHE FRAICHEUR VEG             HYG_AUTRES
# 3643174        HYG_DOUCHE FRAICHEUR VEG             HYG_AUTRES
# 3643175  CORPS_LAIT HUILE PLAISIRNATURE  CORPS_HYDR_LAIT_HUILE
# 3643176                    CAP_AP SHAMP       CAPILLAIRE_AUTRE
# 3643177                    CAP_AP SHAMP       CAPILLAIRE_AUTRE
# 3643178                    CAP_AP SHAMP       CAPILLAIRE_AUTRE
# 3643179          CORPS_LAIT HUILE MONOI            CORPS_MONOI
# 3643180                    CAP_AP SHAMP       CAPILLAIRE_AUTRE
# 3643181           CORPS_EXFOLIANT CORPS   CORPS_SPA_ET_MINCEUR
# 3643182            MAQ_TEINT Font teint              MAQ_TEINT
#
#                                  LIBELLE     CLI_ID
# 3643163    SVC ECLAT COULEUR AP SH 150ML  984943411
# 3643164    SVC ECLAT COULEUR AP SH 150ML  984943411
# 3643165  GEL MOUSS THE VERT FV FL200 REF  984943411
# 3643166          EDT NATURELLE VAPO 75ML  984943411
# 3643167      GEL MOUSS FL200 VERVEINE FV  984943411
# 3643168        SVC NUTRITION AP SH 150ML  984943411
# 3643169        SVC NUTRITION AP SH 150ML  984943411
# 3643170  GEL MOUSS THE VERT FV FL200 REF  984943411
# 3643171         GD JDM4 THE VERT FL200ML  984943411
# 3643172         GD JDM4 THE VERT FL200ML  984943411
# 3643173    FRAICHEUR SH DCHE CHEVREF 200  984943411
# 3643174    FRAICHEUR SH DCHE CHEVREF 200  984943411
# 3643175           LAIT AVOINE PN2 FL50ML  984943411
# 3643176    SVC ECLAT COULEUR AP SH 150ML  984943411
# 3643177    SVC ECLAT COULEUR AP SH 150ML  984943411
# 3643178        SVC NUTRITION AP SH 150ML  984943411
# 3643179           HUILE SECHE MDT 125 ML  984943411
# 3643180    SVC ECLAT COULEUR AP SH 150ML  984943411
# 3643181   EXFOLIANT OLIVE PN2 P200ML VPM  984943411
# 3643182  FDT 0/DEF BEIG300 MEDIUM CN3 30  984943411

# %% [markdown]
# #### Prepare DF

# %%
df_history["LIBELLE"] = pd.Categorical(df_history["LIBELLE"], categories=CATEGORIES)
df_history["LIBELLE"] = df_history["LIBELLE"].cat.codes

df_history["FAMILLE"] = pd.Categorical(df_history["FAMILLE"],
                                       categories=CATEGORIES)
df_history["FAMILLE"] = df_history["FAMILLE"].cat.codes

df_history["MAILLE"] = pd.Categorical(df_history["MAILLE"], categories=CATEGORIES)
df_history["MAILLE"] = df_history["MAILLE"].cat.codes

df_history["UNIVERS"] = pd.Categorical(df_history["UNIVERS"], categories=CATEGORIES)
df_history["UNIVERS"] = df_history["UNIVERS"].cat.codes

df_history.head()
# Out:
#          TICKET_ID  MOIS_VENTE  PRIX_NET  FAMILLE  UNIVERS  MAILLE  LIBELLE  \
# 3643163   32991432           1      2.95     1490     1603    1515      420
# 3643164   32991432           1      2.95     1490     1603    1515      420
# 3643165   32991432           1      1.95     1487     1562    1508      988
# 3643166   32991432           1     17.50     1489     1547    1509     1328
# 3643167   32991432           1      1.95     1487     1562    1508      251
#
#             CLI_ID
# 3643163  984943411
# 3643164  984943411
# 3643165  984943411
# 3643166  984943411
# 3643167  984943411

# %% [markdown]
# #### Load Model

# %%
model = pickle.load(open("..{}models{}model_products_20.pkl".format(os.sep, os.sep), "rb"))

model.labels_
# Out:
# array([2, 2, 2, ..., 3, 3, 3])

# %% [markdown]
# #### Clusterize History

# %%
df_kmean = df_history.copy()
df_kmean = df_kmean[["FAMILLE", "MAILLE", "UNIVERS", "LIBELLE", "PRIX_NET"]]

distance = model.transform(df_kmean)
distance = [sum(elts) for elts in zip(*distance)]

min_value = min(distance)

client_cluster = distance.index(min_value)

client_cluster
# Out:
# 4

# %% [markdown]
# #### Extract products corresponding to Client Cluster

# %% [markdown]
# Get ids of products from cluster

# %%
cluster = np.where(np.isin(model.labels_, client_cluster))[0]

cluster
# Out:
# array([710, 711, 712, 713, 714, 715, 716, 717, 718, 719, 720, 721, 722,
#        723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735,
#        736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748,
#        749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761,
#        762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774,
#        775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787,
#        789], dtype=int64)

# %% [markdown]
# Get products from ids

# %%
df_client = df_products.loc[cluster]

df_client.head(20)
# Out:
#              FAMILLE                       MAILLE  \
# 710          HYGIENE                      HYG_JDM
# 711   SOINS DU CORPS        CORPS_HYDR_LAIT_HUILE
# 712  SOINS DU VISAGE           VIS_JEUNE_ET_LEVRE
# 713       MAQUILLAGE                   MAQ_ONGLES
# 714       MAQUILLAGE     MAQ_YEUX_MASCA_EYEL_FARD
# 715      CAPILLAIRES         CAPILLAIRE_SHAMPOING
# 716       MAQUILLAGE     MAQ_YEUX_MASCA_EYEL_FARD
# 717  SOINS DU VISAGE                      VIS_PUR
# 718  SOINS DU VISAGE    VIS_AAAR_HORS_DEMAQLOTION
# 719       MAQUILLAGE              MAQ_LEV_RAL_HMG
# 720   SOINS DU CORPS  CORPS_HYDRA_NOURRI_ET_SOINS
# 721       MAQUILLAGE                    MAQ_AUTRE
# 722  SOINS DU VISAGE           VIS_JEUNE_ET_LEVRE
# 723       MAQUILLAGE     MAQ_YEUX_MASCA_EYEL_FARD
# 724       MAQUILLAGE                    MAQ_TEINT
# 725       MAQUILLAGE            MAQ_YEUX_MASCA_HG
# 726        PARFUMAGE                  PARF_PARFUM
# 727  SOINS DU VISAGE    VIS_AAAR_HORS_DEMAQLOTION
# 728  SOINS DU VISAGE           VIS_JEUNE_ET_LEVRE
# 729      CAPILLAIRES         CAPILLAIRE_SHAMPOING
#
#                          UNIVERS                                   LIBELLE  \
# 710       HYG_DOUCHE JARDINMONDE              GD JDM HOMME VETIVER FL200ML
# 711      CORPS_LAIT HUILE AUTRES              LAIT CORPS F300 FLEURS CRIST
# 712  VIS_CJOUR Jeunes Specifique          PORE MINIMIZING SERUM SEBOV 30ML
# 713           MAQ_ONG Vernis LUM  VAO TOPCO FUCHIA NACR ITCOL FEV14 L4 3ML
# 714                MAQ_YEUX Fard               FAP CR METAL BRONZE CN3 5ML
# 715         CAP_SHAMP SPECIFIQUE            SVC REFLETS SH REF ARG FL200ML
# 716                MAQ_YEUX Fard   FAP MONO 2013 CN3   2,5G   ROSE  POIVRE
# 717                VIS_DEMAQ PUR                   LINGETTES CALMILLE 2013
# 718               VIS_TRAIT AAAR            ELIXIR 7.9 Int Jeunesse30ml CS
# 719           MAQ_LEV RAL Autres             LAQUE LEVR OCRE/NUDE CN3 09 5
# 720         SOINS CORPS ANTI-AGE            CREME MAINS ANTIRIDES RC T50ml
# 721                   MAQ_Autres                    GRANDE PALETTE CN 2013
# 722              VIS_SOIN LEVRES                BAUME REPARATEUR LEVRES 4G
# 723                MAQ_YEUX Fard               FAP MONO RAISIN NOIR CN3 3g
# 724         MAQ_TEINT Font teint  FDT PUR LIGH BGE 100TT TR CLAIR CN3 30ML
# 725      MAQ_YEUX Mascara Elixir          MASCARA SOIN BRUN02 2014 CN3 9ML
# 726     PARF_PARF ET EAU DE PARF                        EDP MING SHU 30 ML
# 727               VIS_CJOUR AAAR            ANTIRIDE BIENFAIS JOUR 50ml RC
# 728  VIS_TRAIT Jeunes Specifique         SPOT CORRECT PURE SYSTEM T10 10ML
# 729         CAP_SHAMP SPECIFIQUE                SH 100ML POMME DE REINETTE
#
#      PRIX_NET
# 710      1.50
# 711      3.45
# 712     18.00
# 713      1.65
# 714      5.00
# 715      5.90
# 716      6.95
# 717      2.95
# 718     11.95
# 719      7.45
# 720      9.90
# 721     15.25
# 722      1.25
# 723      5.00
# 724     19.90
# 725     11.45
# 726     12.50
# 727     14.00
# 728      5.75
# 729      2.25

# %%
df_client.shape[0]
# Out:
# 79
